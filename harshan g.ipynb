# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset
data=pd.read_csv('C:/Users/ghars/Downloads/titanic_dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Set 'PassengerId' as the index column
data.set_index('PassengerId', inplace=True)
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Check the number of rows and columns
data.shape
# Out:
# (891, 11)

# %%
#get the column names
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Check the data types of each column
data.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
# Check for missing value
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# Check the summary statistics of the numerical columns
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Fill missing values with the mean value for each column
data = data.fillna(data.mean())
data
# Out:
# C:\Users\Basil C Babu\AppData\Local\Temp\ipykernel_7352\765772824.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data = data.fillna(data.mean())
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# ...

# %%
# Fill missing values in the 'Embarked' column with the most common value
data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)

data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
# You could also fill missing values with the mode value for each column
data = data.fillna(data.mode().iloc[0])

# %%
data
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# Use the 'boxplot' method to check for outliers in the 'Age' column
data.boxplot(column='Age')
plt.show()

# %%
from scipy import stats

# Use the 'zscore' function to calculate the z-scores of the 'Fare' column
z_scores = stats.zscore(data['Fare'])



z_scores
# Out:
# PassengerId
# 1     -0.502445
# 2      0.786845
# 3     -0.488854
# 4      0.420730
# 5     -0.486337
#          ...
# 887   -0.386671
# 888   -0.044381
# 889   -0.176263
# 890   -0.044381
# 891   -0.492378
# Name: Fare, Length: 891, dtype: float64

# %%
 # Keep only the rows that have z-scores between -3 and 3
data = data[(z_scores > -3) & (z_scores < 3)]

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
# Use the 'quantile' method to find the 25th and 75th percentile values of the 'Pclass' column
p25 = data['Pclass'].quantile(0.25)
p75 = data['Pclass'].quantile(0.75)

# %%
p25
# Out:
# 2.0

# %%
p75
# Out:
# 3.0

# %%
# Keep only the rows that have 'Pclass' values between the 25th and 75th percentiles
data = data[(data['Pclass'] >= p25) & (data['Pclass'] <= p75)]

# %%
data
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 3                   1       3                    Heikkinen, Miss. Laina
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex        Age  SibSp  Parch            Ticket     Fare Cabin  \
# ...

# %%
# Visualize the distribution of 'Age' to identify outliers
sns.boxplot(data['Age'])
plt.show()
# Out:
# C:\Users\Basil C Babu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Remove outliers using the interquartile range method
q1 = data['Age'].quantile(0.25)
q3 = data['Age'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
data = data[(data['Age'] > lower_bound) & (data['Age'] < upper_bound)]
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 3                   1       3
# 5                   0       3
# 6                   0       3
# 9                   1       3
# ...               ...     ...
# 885                 0       3
# 886                 0       3
# 887                 0       2
# 889                 0       3
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 3                                       Heikkinen, Miss. Laina  female
# 5                                     Allen, Mr. William Henry    male
# 6                                             Moran, Mr. James    male
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# ...                                                        ...     ...
# ...

# %%
# Repeat the process for 'Fare' and 'Pclass'
sns.boxplot(data['Fare'])
q1 = data['Fare'].quantile(0.25)
q3 = data['Fare'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
data = data[(data['Fare'] > lower_bound) & (data['Fare'] < upper_bound)]
# Out:
# C:\Users\Basil C Babu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(data['Pclass'])
q1 = data['Pclass'].quantile(0.25)
q3 = data['Pclass'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
data = data[(data['Pclass'] > lower_bound) & (data['Pclass'] < upper_bound)]
# Out:
# C:\Users\Basil C Babu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Separate the target column from the feature set
target = data['Survived']
features = data.drop(columns='Survived')


features
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
features = data.select_dtypes(include=['float', 'int'])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)

# %%
features_scaled = pd.DataFrame(features_scaled, columns=features.columns)

# %%
# Print the first 5 rows of the scaled feature set
print(features_scaled.head())
# Out:
#    PassengerId  Survived  Pclass       Age  SibSp  Parch      Fare
# 0     0.000000       0.0     1.0  0.271174  0.125    0.0  0.014151
# 1     0.001124       1.0     0.0  0.472229  0.125    0.0  0.139136
# 2     0.002247       1.0     1.0  0.321438  0.000    0.0  0.015469
# 3     0.003371       1.0     0.0  0.434531  0.125    0.0  0.103644
# 4     0.004494       0.0     1.0  0.434531  0.000    0.0  0.015713
